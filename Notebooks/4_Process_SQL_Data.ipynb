# %%
#Libraries
import pandas as pd
from functions import query_to_df

# Set Pandas display options to show all rows and columns
# pd.set_option("display.max_rows", None)  # None means no limit
# pd.set_option("display.max_columns", None)  # None means no limit

# %%
sql = """
SELECT 
    e.*,
    v.VAX_LOT, v.VAX_MANU, v.VAX_DOSE_SERIES,
    s.SYMPTOM1, s.SYMPTOM2, s.SYMPTOM3, s.SYMPTOM4, s.SYMPTOM5
FROM event_data AS e
LEFT JOIN sample_vax_data AS v
ON e.VAERS_ID = v.VAERS_ID
LEFT JOIN sample_sympt_data AS s
ON e.VAERS_ID = s.VAERS_ID
"""
df = query_to_df(sql)
df.head()
# Out:
#    VAERS_ID STATE  AGE_YRS  SEX  DIED  L_THREAT  HOSPITAL  DISABLE  RECOVD  \
# 0    902418    NJ     56.0    0     0         0         0        0       1
# 1    902440    AZ     35.0    0     0         0         0        0       1
# 2    902446    WV     55.0    0     0         0         0        0       1
# 3    902464    LA     42.0    1     0         0         0        0       1
# 4    902465    AR     60.0    0     0         0         0        0       0
#
#      VAX_DATE  BIRTH_DEFECT VAX_LOT         VAX_MANU VAX_DOSE_SERIES  \
# 0  12/15/2020             0  EH9899  PFIZER\BIONTECH               1
# 1  12/15/2020             0  EH9899  PFIZER\BIONTECH               1
# 2  12/15/2020             0  EH9899  PFIZER\BIONTECH               1
# 3  12/15/2020             0
# 4  12/15/2020             0  EH9899  PFIZER\BIONTECH               1
#
#               SYMPTOM1                      SYMPTOM2       SYMPTOM3  \
# 0        hypoaesthesia  injection site hypoaesthesia
# 1             headache
# 2             erythema                   feeling hot       flushing
# 3            dizziness      electrocardiogram normal  hyperhidrosis
# 4  sensory disturbance                        tremor
#
#                  SYMPTOM4    SYMPTOM5
# 0
# 1
# 2
# 3  laboratory test normal  presyncope
# 4

# %%
df.to_csv("raw_sql_data.csv")

# %%
# Drop rows where 'VAX_LOT' or 'VAX_MANU' have null values
df = df.dropna(subset=['VAX_LOT', 'VAX_MANU'])

# %%
# Replace empty symptom fields with "None"
symptom_columns = ['SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5']
df[symptom_columns] = df[symptom_columns].replace('', 'None')

# %%
# Combine SYMPTOM1 to SYMPTOM5 into a single column
df['ALL_SYMPTOMS'] = df[symptom_columns].apply(lambda x: ','.join(x.dropna().astype(str)), axis=1)

# %%
# Apply One-Hot Encoding on the combined symptoms
symptom_dummies = df['ALL_SYMPTOMS'].str.get_dummies(sep=',')

# Merge the one-hot encoded symptoms back into the original dataframe
df = pd.concat([df, symptom_dummies], axis=1)

# %%
# Display all column names
list(df.columns)
# Out:
# ['VAERS_ID',
#  'STATE',
#  'AGE_YRS',
#  'SEX',
#  'DIED',
#  'L_THREAT',
#  'HOSPITAL',
#  'DISABLE',
#  'RECOVD',
#  'VAX_DATE',
#  'BIRTH_DEFECT',
#  'VAX_LOT',
#  'VAX_MANU',
#  'VAX_DOSE_SERIES',
#  'SYMPTOM1',
#  'SYMPTOM2',
#  'SYMPTOM3',
#  'SYMPTOM4',
#  'SYMPTOM5',
#  'ALL_SYMPTOMS',
#  ' insomnia type',
#  ' visual',
#  'None',
#  'abdominal adhesions',
#  'abdominal discomfort',
#  'abdominal distension',
#  'abdominal pain',
#  'abdominal pain lower',
#  'abdominal pain upper',
#  'abdominal rigidity',
#  'abnormal behaviour',
#  'abnormal dreams',
#  'abnormal sensation in eye',
#  'abortion spontaneous',
#  'abscess',
#  'acne',
#  'acoustic stimulation tests',
#  'acoustic stimulation tests abnormal',
#  'activated partial thromboplastin time',
#  'activated partial thromboplastin time normal',
#  'activated partial thromboplastin time shortened',
#  'acute coronary syndrome',
#  'acute disseminated encephalomyelitis',
#  'acute generalised exanthematous pustulosis',
#  'acute kidney injury',
#  'acute myocardial infarction',
#  'acute respiratory failure',
#  'adjusted calcium increased',
#  'administration site joint movement impairment',
#  'administration site pain',
#  'administration site swelling',
#  'adnexa uteri mass',
#  'adult failure to thrive',
#  'adverse drug reaction',
#  'adverse event',
#  'adverse reaction',
#  'affect lability',
#  'ageusia',
#  'aggression',
#  'agitation',
#  'alanine aminotransferase',
#  'alanine aminotransferase increased',
#  'alanine aminotransferase normal',
#  'albumin globulin ratio',
#  'alcohol interaction',
#  "allen's test",
#  'allergy test',
#  'allergy test positive',
#  'allergy to synthetic fabric',
#  'allergy to vaccine',
#  'alopecia',
#  'alpha 1 globulin normal',
#  'altered state of consciousness',
#  'altered visual depth perception',
#  'amino acid level',
#  'amnesia',
#  'amphetamines positive',
#  'amylase',
#  'amylase normal',
#  'anaemia',
#  'anaesthesia oral',
#  'anal incontinence',
#  'anaphylactic reaction',
#  'anaphylactic shock',
#  'anaphylactoid reaction',
#  'anger',
#  'angina pectoris',
#  'angina unstable',
#  'angiocardiogram',
#  'angioedema',
#  'angiogram',
#  'angiogram abnormal',
#  'angiogram cerebral',
#  'angiogram cerebral abnormal',
#  'angiogram cerebral normal',
#  'angiogram normal',
#  'angiogram pulmonary abnormal',
#  'angiogram pulmonary normal',
#  'angiogram retina abnormal',
#  'angiopathy',
#  'angioplasty',
#  'anion gap',
#  'anion gap decreased',
#  'anion gap increased',
#  'anion gap normal',
#  'anorectal discomfort',
#  'anosmia',
#  'anterograde amnesia',
#  'antibiotic therapy',
#  'antibody test',
#  'antibody test abnormal',
#  'antibody test positive',
#  'anticoagulant therapy',
#  'anticonvulsant drug level',
#  'antidepressant drug level',
#  'antineutrophil cytoplasmic antibody',
#  'antineutrophil cytoplasmic antibody negative',
#  'antinuclear antibody',
#  'antinuclear antibody negative',
#  'antinuclear antibody positive',
#  'antiphospholipid antibodies',
#  'antipsychotic drug level',
#  'antithrombin iii',
#  'anxiety',
#  'apathy',
#  'aphasia',
#  'aphonia',
#  'aphthous ulcer',
#  'apnoea',
#  'appendicectomy',
#  'appendicitis',
#  'appendicolith',
#  'appetite disorder',
#  'areflexia',
#  'arrhythmia',
#  'arteriogram carotid',
#  'arteriogram carotid normal',
#  'arteriospasm coronary',
#  'arthralgia',
#  'arthritis',
#  'arthritis bacterial',
#  'arthropathy',
#  'arthropod bite',
#  'aspartate aminotransferase',
#  'aspartate aminotransferase increased',
#  'aspartate aminotransferase normal',
#  'aspiration bursa',
#  'asthenia',
#  'asthenopia',
#  'asthma',
#  'asymptomatic covid-19',
#  'ataxia',
#  'atelectasis',
#  'atopy',
#  'atrial fibrillation',
#  'atrial tachycardia',
#  'audiogram',
#  'audiogram abnormal',
#  'auditory disorder',
#  'aura',
#  'auscultation',
#  'autoantibody positive',
#  'autoimmune disorder',
#  'autopsy',
#  'autoscopy',
#  'axillary mass',
#  'axillary pain',
#  'back injury',
#  'back pain',
#  'bacteraemia',
#  'bacterial infection',
#  'bacterial test',
#  'bacterial test negative',
#  'bacterial test positive',
#  'balance disorder',
#  'band neutrophil percentage increased',
#  'barbiturates positive',
#  'base excess',
#  'base excess decreased',
#  'basophil count decreased',
#  'basophil count normal',
#  'basophil percentage',
#  'basophil percentage decreased',
#  'bed rest',
#  'bedridden',
#  "bell's palsy",
#  'bile duct stone',
#  'bilevel positive airway pressure',
#  'biliary dilatation',
#  'bilirubin urine present',
#  'binocular eye movement disorder',
#  'biopsy',
#  'biopsy brain',
#  'biopsy skin abnormal',
#  'bladder catheter replacement',
#  'bladder catheterisation',
#  'blepharitis',
#  'blepharospasm',
#  'blindness',
#  'blindness transient',
#  'blindness unilateral',
#  'blister',
#  'blister rupture',
#  'blood albumin',
#  'blood albumin decreased',
#  'blood albumin increased',
#  'blood albumin normal',
#  'blood alkaline phosphatase increased',
#  'blood alkaline phosphatase normal',
#  'blood bicarbonate normal',
#  'blood bilirubin decreased',
#  'blood bilirubin increased',
#  'blood bilirubin normal',
#  'blood calcium',
#  'blood calcium decreased',
#  'blood calcium increased',
#  'blood calcium normal',
#  'blood catecholamines',
#  'blood chloride decreased',
#  'blood chloride increased',
#  'blood chloride normal',
#  'blood cholesterol',
#  'blood cholesterol increased',
#  'blood cholesterol normal',
#  'blood count',
#  'blood count abnormal',
#  'blood creatine increased',
#  'blood creatine normal',
#  'blood creatine phosphokinase',
#  'blood creatine phosphokinase decreased',
#  'blood creatine phosphokinase increased',
#  'blood creatine phosphokinase normal',
#  'blood creatinine',
#  'blood creatinine decreased',
#  'blood creatinine increased',
#  'blood creatinine normal',
#  'blood culture',
#  'blood culture negative',
#  'blood electrolytes',
#  'blood electrolytes normal',
#  'blood folate normal',
#  'blood gases',
#  'blood gases abnormal',
#  'blood gases normal',
#  'blood glucose',
#  'blood glucose abnormal',
#  'blood glucose decreased',
#  'blood glucose increased',
#  'blood glucose normal',
#  'blood heavy metal abnormal',
#  'blood heavy metal test',
#  'blood hiv rna below assay limit',
#  'blood homocysteine',
#  'blood immunoglobulin e',
#  'blood immunoglobulin g',
#  'blood insulin increased',
#  'blood iron',
#  'blood iron normal',
#  'blood ketone body',
#  'blood lactate dehydrogenase',
#  'blood lactate dehydrogenase increased',
#  'blood lactate dehydrogenase normal',
#  'blood lactic acid',
#  'blood lactic acid decreased',
#  'blood lactic acid increased',
#  'blood lactic acid normal',
#  'blood magnesium',
#  'blood magnesium decreased',
#  'blood magnesium increased',
#  'blood magnesium normal',
#  'blood mercury abnormal',
#  'blood osmolarity decreased',
#  'blood osmolarity increased',
#  'blood parathyroid hormone increased',
#  'blood ph',
#  'blood ph increased',
#  'blood ph normal',
#  'blood phosphorus',
#  'blood phosphorus decreased',
#  'blood phosphorus normal',
#  'blood potassium',
#  'blood potassium decreased',
#  'blood potassium increased',
#  'blood potassium normal',
#  'blood pressure abnormal',
#  'blood pressure decreased',
#  'blood pressure diastolic decreased',
#  'blood pressure diastolic increased',
#  'blood pressure fluctuation',
#  'blood pressure immeasurable',
#  'blood pressure increased',
#  'blood pressure measurement',
#  'blood pressure normal',
#  'blood pressure orthostatic abnormal',
#  'blood pressure orthostatic normal',
#  'blood pressure systolic',
#  'blood pressure systolic abnormal',
#  'blood pressure systolic decreased',
#  'blood pressure systolic increased',
#  'blood pressure systolic normal',
#  'blood sodium decreased',
#  'blood sodium increased',
#  'blood sodium normal',
#  'blood test',
#  'blood test abnormal',
#  'blood test normal',
#  'blood thyroid stimulating hormone',
#  'blood thyroid stimulating hormone decreased',
#  'blood thyroid stimulating hormone increased',
#  'blood thyroid stimulating hormone normal',
#  'blood triglycerides increased',
#  'blood triglycerides normal',
#  'blood urea',
#  'blood urea decreased',
#  'blood urea increased',
#  'blood urea nitrogen/creatinine ratio',
#  'blood urea nitrogen/creatinine ratio increased',
#  'blood urea normal',
#  'blood uric acid',
#  'blood uric acid normal',
#  'blood urine present',
#  'body height',
#  'body mass index',
#  'body temperature',
#  'body temperature abnormal',
#  'body temperature decreased',
#  'body temperature increased',
#  'bone density abnormal',
#  'bone pain',
#  'bone swelling',
#  'borrelia test negative',
#  'bowel movement irregularity',
#  'bradycardia',
#  'bradykinesia',
#  'bradyphrenia',
#  'brain natriuretic peptide',
#  'brain natriuretic peptide increased',
#  'brain natriuretic peptide normal',
#  'breakthrough pain',
#  'breast engorgement',
#  'breast feeding',
#  'breast inflammation',
#  'breast mass',
#  'breast milk discolouration',
#  'breast oedema',
#  'breast pain',
#  'breast swelling',
#  'breast tenderness',
#  'breath sounds',
#  'breath sounds abnormal',
#  'breath sounds normal',
#  'bronchial hyperreactivity',
#  'bronchitis',
#  'bronchospasm',
#  'bruxism',
#  'bundle branch block right',
#  'burning sensation',
#  'bursitis',
#  'butterfly rash',
#  'c-reactive protein',
#  'c-reactive protein decreased',
#  'c-reactive protein increased',
#  'c-reactive protein normal',
#  'calcium ionised decreased',
#  'calcium ionised normal',
#  'candida infection',
#  'capillary nail refill test abnormal',
#  'carbon dioxide',
#  'carbon dioxide decreased',
#  'carbon dioxide increased',
#  'carbon dioxide normal',
#  'cardiac arrest',
#  'cardiac assistance device user',
#  'cardiac discomfort',
#  'cardiac disorder',
#  'cardiac failure',
#  'cardiac failure congestive',
#  'cardiac flutter',
#  'cardiac monitoring',
#  'cardiac monitoring abnormal',
#  'cardiac monitoring normal',
#  'cardiac pacemaker insertion',
#  'cardiac stress test normal',
#  'cardiac telemetry',
#  'cardiac telemetry normal',
#  'cardio-respiratory arrest',
#  'cardiomegaly',
#  'cardiopulmonary failure',
#  'cardiovascular evaluation',
#  'cardioversion',
#  'carotid pulse abnormal',
#  'catatonia',
#  'catecholamines urine',
#  'catheterisation cardiac',
#  'catheterisation cardiac abnormal',
#  'catheterisation cardiac normal',
#  'cd4 lymphocyte percentage decreased',
#  'cellulitis',
#  'central nervous system lesion',
#  'cerebellar ataxia',
#  'cerebrovascular accident',
#  'cervical radiculopathy',
#  'chapped lips',
#  'cheilitis',
#  'chest discomfort',
#  'chest pain',
#  'chest scan',
#  'chest x-ray',
#  'chest x-ray abnormal',
#  'chest x-ray normal',
#  'chills',
#  'chlamydia test',
#  'choking',
#  'choking sensation',
#  'cholecystectomy',
#  'cholelithiasis',
#  'chorioretinopathy',
#  'chromaturia',
#  'chronic kidney disease',
#  'chronic spontaneous urticaria',
#  'circumoral oedema',
#  'circumoral swelling',
#  'circumstance or information capable of leading to medication error',
#  'claustrophobia',
#  'clonic convulsion',
#  'clumsiness',
#  'cluster headache',
#  'coagulation factor v level',
#  'coagulation factor xii level',
#  'coagulation test',
#  'coagulation time',
#  'coccydynia',
#  'cognitive disorder',
#  'cold sweat',
#  'colitis',
#  'colitis ulcerative',
#  'colostomy',
#  'coma scale abnormal',
#  'coma scale normal',
#  'comminuted fracture',
#  'complement factor',
#  'complex regional pain syndrome',
#  'computerised tomogram',
#  'computerised tomogram abdomen',
#  'computerised tomogram abdomen abnormal',
#  'computerised tomogram abdomen normal',
#  'computerised tomogram abnormal',
#  'computerised tomogram coronary artery',
#  'computerised tomogram coronary artery normal',
#  'computerised tomogram head',
#  'computerised tomogram head abnormal',
#  'computerised tomogram head normal',
#  'computerised tomogram neck',
#  'computerised tomogram normal',
#  'computerised tomogram pancreas abnormal',
#  'computerised tomogram pelvis',
#  'computerised tomogram spine',
#  'computerised tomogram thorax',
#  'computerised tomogram thorax abnormal',
#  'computerised tomogram thorax normal',
#  'condition aggravated',
#  'confusional state',
#  'conjunctival haemorrhage',
#  'conjunctival hyperaemia',
#  'conjunctivitis',
#  'conjunctivitis allergic',
#  'consciousness fluctuating',
#  'constipation',
#  'continuous positive airway pressure',
#  'contraindicated product administered',
#  'contraindication to vaccination',
#  'contusion',
#  'cooling therapy',
#  'coordination abnormal',
#  'corneal oedema',
#  'corneal reflex decreased',
#  'coronary arterial stent insertion',
#  'coronary artery disease',
#  'coronary artery occlusion',
#  'coronary artery stenosis',
#  'coronavirus infection',
#  'coronavirus test positive',
#  'costochondritis',
#  'cough',
#  'cough variant asthma',
#  'covid-19',
#  'covid-19 immunisation',
#  'covid-19 pneumonia',
#  'coxsackie virus test positive',
#  'cranial nerve disorder',
#  'craniotomy',
#  'creatinine renal clearance decreased',
#  'crying',
#  'cryoglobulins',
#  'cryptococcus test',
#  'csf culture negative',
#  'csf glucose normal',
#  'csf mononuclear cell count increased',
#  'csf polymorphonuclear cell count increased',
#  'csf protein normal',
#  'csf red blood cell count positive',
#  'csf test',
#  'csf virus no organisms observed',
#  'csf white blood cell count increased',
#  'culture',
#  'culture positive',
#  'culture stool',
#  'culture stool negative',
#  'culture urine',
#  'culture urine negative',
#  'culture wound positive',
#  'cyanosis',
#  'cytokine storm',
#  'cytomegalovirus test',
#  'dark circles under eyes',
#  'deafness',
#  'deafness neurosensory',
#  'deafness unilateral',
#  'death',
#  'decerebrate posture',
#  'decreased appetite',
#  'deep vein thrombosis',
#  'defaecation urgency',
#  'dehydration',
#  'deja vu',
#  'delirium',
#  'delusion',
#  'dementia',
#  'demyelination',
#  'dental examination normal',
#  'dental paraesthesia',
#  'depersonalisation/derealisation disorder',
#  'depressed level of consciousness',
#  'depressed mood',
#  'depression',
#  'derealisation',
#  'dermatillomania',
#  'dermatitis',
#  'dermatitis acneiform',
#  'dermatitis allergic',
#  'dermatitis contact',
#  'dermatitis exfoliative generalised',
#  'dermatitis psoriasiform',
#  'dermatophagia',
#  'device connection issue',
#  'device malfunction',
#  'diabetes mellitus',
#  'diagnostic procedure',
#  'dialysis',
#  'diaphragmalgia',
#  'diaphragmatic spasm',
#  'diarrhoea',
#  'diarrhoea haemorrhagic',
#  'differential white blood cell count',
#  'differential white blood cell count abnormal',
#  'differential white blood cell count normal',
#  'diplopia',
#  'directional doppler flow tests',
#  'disability',
#  'discomfort',
#  'disease recurrence',
#  'disorientation',
#  'dissociation',
#  'dissociative disorder',
#  'disturbance in attention',
#  'diverticulitis',
#  'dizziness',
#  'dizziness postural',
#  'drainage',
#  'drooling',
#  'drug eruption',
#  'drug hypersensitivity',
#  'drug ineffective',
#  'drug screen',
#  'drug screen negative',
#  'drug screen positive',
#  'dry eye',
#  'dry mouth',
#  'dry skin',
#  'dry throat',
#  'dysacusis',
#  'dysarthria',
#  'dyschezia',
#  'dyschromatopsia',
#  'dysgeusia',
#  'dyshidrotic eczema',
#  'dyskinesia',
#  'dysmenorrhoea',
#  'dyspepsia',
#  'dysphagia',
#  'dysphemia',
#  'dysphonia',
#  'dyspnoea',
#  'dyspnoea exertional',
#  'dyspnoea paroxysmal nocturnal',
#  'dysstasia',
#  'dystonic tremor',
#  'dysuria',
#  'ear congestion',
#  'ear discomfort',
#  'ear disorder',
#  'ear haemorrhage',
#  'ear infection',
#  'ear pain',
#  'ear pruritus',
#  'ear swelling',
#  'eating disorder',
#  'ecchymosis',
#  'echocardiogram',
#  'echocardiogram abnormal',
#  'echocardiogram normal',
#  'eczema',
#  'eczema eyelids',
#  'ejection fraction decreased',
#  'ejection fraction normal',
#  'electrocardiogram',
#  'electrocardiogram abnormal',
#  'electrocardiogram ambulatory',
#  'electrocardiogram ambulatory abnormal',
#  'electrocardiogram change',
#  'electrocardiogram normal',
#  'electrocardiogram pr shortened',
#  'electrocardiogram q wave abnormal',
#  'electrocardiogram qrs complex normal',
#  'electrocardiogram qt prolonged',
#  'electrocardiogram st segment depression',
#  'electrocardiogram st segment elevation',
#  'electrocardiogram st segment normal',
#  'electrocardiogram t wave abnormal',
#  'electrocardiogram t wave inversion',
#  'electrocardiogram t wave peaked',
#  'electroencephalogram',
#  'electroencephalogram normal',
#  'electromyogram',
#  'electromyogram normal',
#  'emotional distress',
#  'encephalopathy',
#  'endometriosis',
#  'endothelial dysfunction',
#  'endotracheal intubation',
#  'enema administration',
#  'energy increased',
#  'enlarged uvula',
#  'enthesopathy',
#  'eosinophil count decreased',
#  'eosinophil count increased',
#  'eosinophil count normal',
#  'eosinophil percentage',
#  'eosinophil percentage decreased',
#  'eosinophil percentage increased',
#  'epicondylitis',
#  'epididymitis',
#  'epigastric discomfort',
#  'epiglottitis',
#  'epinephrine',
#  'epistaxis',
#  'eructation',
#  'erythema',
#  'erythema multiforme',
#  'erythema nodosum',
#  'erythema of eyelid',
#  'euphoric mood',
#  'eustachian tube obstruction',
#  'exercise tolerance decreased',
#  'exposure during pregnancy',
#  'exposure to sars-cov-2',
#  'exposure via breast milk',
#  'exposure via skin contact',
#  'extensive swelling of vaccinated limb',
#  'extra dose administered',
#  'extraocular muscle paresis',
#  'extrasystoles',
#  'extremity contracture',
#  'eye discharge',
#  'eye disorder',
#  'eye haemorrhage',
#  'eye infection',
#  'eye inflammation',
#  'eye irrigation',
#  'eye irritation',
#  'eye movement disorder',
#  'eye oedema',
#  'eye pain',
#  'eye pruritus',
#  'eye swelling',
#  'eyelid contusion',
#  'eyelid disorder',
#  'eyelid function disorder',
#  'eyelid irritation',
#  'eyelid margin crusting',
#  'eyelid oedema',
#  'eyelid pain',
#  'eyelid ptosis',
#  'eyelid rash',
#  'eyelid sensory disorder',
#  'eyelids pruritus',
#  'face injury',
#  'face oedema',
#  'facial asymmetry',
#  'facial bones fracture',
#  'facial discomfort',
#  'facial nerve disorder',
#  'facial pain',
#  'facial paralysis',
#  'facial paresis',
#  'facial spasm',
#  'faeces discoloured',
#  'faeces pale',
#  'faeces soft',
#  'fall',
#  'fasting',
#  'fatigue',
#  'fear',
#  'fear of eating',
#  'fear of injection',
#  'feeding disorder',
#  'feeling abnormal',
#  'feeling cold',
#  'feeling drunk',
#  'feeling hot',
#  'feeling jittery',
#  'feeling of body temperature change',
#  'feeling of despair',
#  'feeling of relaxation',
#  'fibrin d dimer',
#  'fibrin d dimer increased',
#  'fibrin d dimer normal',
#  'fibromyalgia',
#  'fine motor skill dysfunction',
#  'flank pain',
#  'flatulence',
#  'fluid intake reduced',
#  'fluid retention',
#  'flushing',
#  'foaming at mouth',
#  'foetal death',
#  'foetal exposure during pregnancy',
#  'foetal heart rate abnormal',
#  'foetal hypokinesia',
#  'foetal monitoring',
#  'folliculitis',
#  'food allergy',
#  'food aversion',
#  'food intolerance',
#  'food poisoning',
#  'foreign body sensation in eyes',
#  'formication',
#  'fracture',
#  'freezing phenomenon',
#  'frequent bowel movements',
#  'frustration tolerance decreased',
#  'full blood count',
#  'full blood count abnormal',
#  'full blood count normal',
#  'fungal infection',
#  'gait deviation',
#  'gait disturbance',
#  'gait inability',
#  'gallbladder disorder',
#  'gastric dilatation',
#  'gastric disorder',
#  'gastritis',
#  'gastroenteritis',
#  'gastrointestinal disorder',
#  'gastrointestinal haemorrhage',
#  'gastrointestinal inflammation',
#  'gastrointestinal pain',
#  'gastrointestinal pathogen panel',
#  'gastrointestinal sounds abnormal',
#  'gastrointestinal wall thickening',
#  'gastrooesophageal reflux disease',
#  'gastrostomy',
#  'gaze palsy',
#  'gene mutation identification test',
#  'general physical condition abnormal',
#  'general physical condition normal',
#  'general physical health deterioration',
#  'general symptom',
#  'generalised oedema',
#  'generalised tonic-clonic seizure',
#  'genital blister',
#  'genital herpes',
#  'genital hypoaesthesia',
#  'genital rash',
#  'genital swelling',
#  'genital ulceration',
#  'giant cell arteritis',
#  'gingival bleeding',
#  'gingival discolouration',
#  'gingival disorder',
#  'gingival erythema',
#  'gingival pain',
#  'gingival pruritus',
#  'gingival swelling',
#  'gingivitis',
#  'glassy eyes',
#  'globulin',
#  'globulins increased',
#  'glomerular filtration rate',
#  'glomerular filtration rate decreased',
#  'glomerular filtration rate normal',
#  'glossitis',
#  'glossodynia',
#  'glucose tolerance impaired',
#  'glucose urine absent',
#  'glucose urine present',
#  'glycosylated haemoglobin',
#  'glycosylated haemoglobin decreased',
#  'glycosylated haemoglobin increased',
#  'gonorrhoea',
#  'gout',
#  'gram stain positive',
#  'granulocyte count',
#  'granulocyte percentage',
#  'grip strength decreased',
#  'groin pain',
#  'guillain-barre syndrome',
#  'haematemesis',
#  'haematochezia',
#  'haematocrit',
#  'haematocrit decreased',
#  'haematocrit increased',
#  'haematocrit normal',
#  'haematology test',
#  'haematology test normal',
#  'haematoma',
#  'haematoma muscle',
#  'haematospermia',
#  'haematuria',
#  'haemodialysis',
#  'haemoglobin',
#  'haemoglobin decreased',
#  'haemoglobin normal',
#  'haemoptysis',
#  'haemorrhage',
#  'haemorrhage intracranial',
#  'haemorrhagic stroke',
#  'haemorrhoids',
#  'hallucination',
#  'halo vision',
#  'hangover',
#  'head discomfort',
#  'head injury',
#  'head titubation',
#  'headache',
#  'heart rate',
#  'heart rate abnormal',
#  'heart rate decreased',
#  'heart rate increased',
#  'heart rate irregular',
#  'heart rate normal',
#  'heart sounds abnormal',
#  'heat therapy',
#  'helicobacter test positive',
#  'hemiparaesthesia',
#  'hemiparesis',
#  'hemiplegic migraine',
#  'hepatic enzyme',
#  'hepatic enzyme increased',
#  'hepatic pain',
#  'hepatitis a virus test',
#  'hepatitis b test negative',
#  'hepatitis c antibody negative',
#  'hepatitis c test negative',
#  'herpangina',
#  'herpes simplex',
#  'herpes simplex reactivation',
#  'herpes simplex test negative',
#  'herpes virus infection',
#  'herpes virus test',
#  'herpes zoster',
#  'herpes zoster cutaneous disseminated',
#  'herpes zoster reactivation',
#  'hiccups',
#  'hidradenitis',
#  'high density lipoprotein decreased',
#  'hip arthroplasty',
#  'hip fracture',
#  'histamine abnormal',
#  'histamine intolerance',
#  'histamine level',
#  'histamine level increased',
#  'histamine release test',
#  'hiv antibody negative',
#  'hiv test',
#  'hiv test negative',
#  'hiv test positive',
#  'holmes-adie pupil',
#  'hordeolum',
#  'hospice care',
#  'hot flush',
#  'human chorionic gonadotropin',
#  'human chorionic gonadotropin decreased',
#  'human chorionic gonadotropin negative',
#  'human chorionic gonadotropin positive',
#  'hunger',
#  'hydrops foetalis',
#  'hyperacusis',
#  'hyperaesthesia',
#  'hyperaesthesia teeth',
#  'hypercalcaemia',
#  'hyperglycaemia',
#  'hyperhidrosis',
#  'hyperkalaemia',
#  'hypermagnesaemia',
#  'hypermetropia',
#  'hypernatraemia',
#  'hyperreflexia',
#  'hypersensitivity',
#  'hypersensitivity vasculitis',
#  'hypersomnia',
#  'hypertension',
#  'hypertensive crisis',
#  'hypertensive emergency',
#  'hypertensive urgency',
#  'hyperthyroidism',
#  'hypertonia',
#  'hypertrophy',
#  'hyperventilation',
#  'hypervigilance',
#  'hypnopompic hallucination',
#  'hypoacusis',
#  'hypoaesthesia',
#  'hypoaesthesia eye',
#  'hypoaesthesia oral',
#  'hypocalcaemia',
#  'hypocapnia',
#  'hypogeusia',
#  'hypoglycaemia',
#  'hypokalaemia',
#  'hypokinesia',
#  'hyponatraemia',
#  'hypophagia',
#  'hypophosphataemia',
#  'hypopnoea',
#  'hyporesponsive to stimuli',
#  'hyposmia',
#  'hypotension',
#  'hypothermia',
#  'hypothyroidism',
#  'hypotonia',
#  'hypoxia',
#  'hysteroscopy',
#  'ill-defined disorder',
#  'illness',
#  'illusion',
#  'imaging procedure',
#  'immature granulocyte count increased',
#  'immature granulocyte percentage increased',
#  'immediate post-injection reaction',
#  'immune thrombocytopenia',
#  'immune-mediated adverse reaction',
#  'immunisation',
#  'immunisation anxiety related reaction',
#  'immunoglobulin therapy',
#  'immunoglobulins decreased',
#  'impaired driving ability',
#  'impaired gastric emptying',
#  'impaired work ability',
#  'implant site pruritus',
#  'impulsive behaviour',
#  'inappropriate affect',
#  'inappropriate schedule of product administration',
#  'incisional drainage',
#  'incoherent',
#  'incomplete course of vaccination',
#  'incontinence',
#  'incorrect dose administered',
#  'incorrect product formulation administered',
#  'incorrect route of product administration',
#  'increased appetite',
#  'increased insulin requirement',
#  'increased upper airway secretion',
#  'increased viscosity of upper respiratory secretion',
#  'induration',
#  'infant irritability',
#  'infection',
#  'infectious mononucleosis',
#  'inflammation',
#  'inflammatory marker test',
#  'influenza',
#  'influenza a virus test',
#  'influenza a virus test negative',
#  'influenza b virus test',
#  'influenza like illness',
#  'influenza virus test',
#  'influenza virus test negative',
#  'influenza virus test positive',
#  'infusion site joint movement impairment',
#  'infusion site warmth',
#  'initial insomnia',
#  'injected limb mobility decreased',
#  'injection related reaction',
#  'injection site abscess',
#  'injection site bruising',
#  'injection site cellulitis',
#  'injection site coldness',
#  'injection site dermatitis',
#  'injection site discolouration',
#  'injection site discomfort',
#  ...]

# %%
# Select the symptom columns
sympt_cols_df = df.iloc[:, -2036:]
# Calculate the occurrences of each symptom
symptom_counts = sympt_cols_df.sum(axis=0)

# %%
# Create a DataFrame to display the column names and their counts
symptom_table = pd.DataFrame({
    "Symptom": symptom_counts.index,
    "Occurrences": symptom_counts.values
})
# Sort the table by occurrences in descending order
symptom_table_sorted = symptom_table.sort_values(by="Occurrences", ascending=False)
# Display the sorted table
display(symptom_table_sorted)
# Out:
#                                                 Symptom  Occurrences
# 2                                                  None        16730
# 824                                            headache         4863
# 390                                              chills         3549
# 691                                             fatigue         3423
# 1546                                            pyrexia         3390
# 1377                                               pain         3250
# 1276                                             nausea         2947
# 546                                           dizziness         2753
# 1001                                injection site pain         2363
# 1379                                  pain in extremity         2040
# 981                             injection site erythema         1570
# 1250                                            myalgia         1546
# 1527                                           pruritus         1364
# 118                                          arthralgia         1327
# 1014                            injection site swelling         1255
# 1396                                       paraesthesia         1151
# 1552                                               rash         1098
# 572                                            dyspnoea         1025
# 1006                            injection site pruritus          894
# 1919                                          urticaria          882
# 637                                            erythema          874
# 2003                                           vomiting          867
# 1017                              injection site warmth          863
# 902                                       hypoaesthesia          831
# 713                                            flushing          804
# 531                                           diarrhoea          746
# 1155                                            malaise          709
# 882                                       hyperhidrosis          699
# 1389                                       palpitations          677
# 1131                                    lymphadenopathy          663
# 127                                            asthenia          659
# 828                                heart rate increased          649
# 463                                               cough          641
# 384                                    chest discomfort          587
# 696                                    feeling abnormal          570
# 1398                                  paraesthesia oral          570
# 1771                                        tachycardia          568
# 699                                         feeling hot          562
# 1630                           sars-cov-2 test negative          508
# 1363                                 oropharyngeal pain          447
# 1796                                  throat irritation          434
# 1846                                             tremor          434
# 1424                                peripheral swelling          431
# 270                            blood pressure increased          412
# 306                          body temperature increased          410
# 1705                                          skin warm          385
# 1797                                   throat tightness          384
# 1278                                          neck pain          370
# 1760                                           swelling          366
# 148                                           back pain          359
# 904                                  hypoaesthesia oral          342
# 385                                          chest pain          334
# 1553                                  rash erythematous          326
# 988                           injection site induration          323
# 103                                             anxiety          309
# 1631                           sars-cov-2 test positive          306
# 929                   immediate post-injection reaction          286
# 1008                                injection site rash          282
# 1627                                    sars-cov-2 test          274
# 1761                                      swelling face          269
# 938                               impaired work ability          264
# 500                                  decreased appetite          254
# 1559                                      rash pruritic          246
# 564                                           dysgeusia          246
# 595                                   electrocardiogram          242
# 891                                        hypertension          235
# 1202                                           migraine          230
# 440                                condition aggravated          229
# 1780                                         tenderness          225
# 1617                                        rhinorrhoea          223
# 569                                           dysphagia          218
# 1208                                 mobility decreased          214
# 1009                            injection site reaction          213
# 1100                                       lip swelling          210
# 1707                                     sleep disorder          208
# 870                                           hot flush          208
# 6                                        abdominal pain          207
# 697                                        feeling cold          205
# 1763                                     swollen tongue          204
# 1128                                    lymph node pain          202
# 1434                                pharyngeal swelling          198
# 1087                                    limb discomfort          195
# 146                                       axillary pain          195
# 336                                   burning sensation          193
# 1249                          musculoskeletal stiffness          193
# 1946                              vaccination site pain          190
# 1265                                   nasal congestion          188
# 600                            electrocardiogram normal          186
# 731                                    full blood count          171
# 1244                                  muscular weakness          169
# 1554                                       rash macular          169
# 8                                  abdominal pain upper          168
# 413                                          cold sweat          167
# 1309                                   no adverse event          165
# 465                                            covid-19          162
# 1764                                            syncope          161
# 964                              influenza like illness          161
# 1387                                             pallor          161
# 1986                                     vision blurred          157
# 4                                  abdominal discomfort          157
# 1974                                            vertigo          154
# 971                    injected limb mobility decreased          150
# 1063                                    laboratory test          149
# 1080                                           lethargy          148
# 1488                                         presyncope          142
# 996                                 injection site mass          141
# 1192                            metabolic function test          139
# 1598                       respiratory tract congestion          138
# 1239                                      muscle spasms          137
# 1719                                         somnolence          131
# 37                                              ageusia          126
# 539                                          discomfort          122
# 1558                                       rash papular          120
# 733                             full blood count normal          119
# 1015                           injection site urticaria          118
# 888                                    hypersensitivity          116
# 1020                                           insomnia          113
# 2014                                           wheezing          109
# 1813                                           tinnitus          109
# 86                                              anosmia          107
# 1423                                peripheral coldness          107
# 1653                          sensation of foreign body          107
# 1304                                       night sweats          107
# 583                                            ear pain          106
# 683                                    facial paralysis          106
# 387                                         chest x-ray          106
# 283                                          blood test          106
# 954                                          induration          104
# 571                                           dysphonia          104
# 664                                        eye swelling          102
# 1115                              loss of consciousness           99
# 303                                    body temperature           95
# 557                                           dry mouth           95
# 228                                blood glucose normal           92
# 389                                  chest x-ray normal           90
# 736                                    gait disturbance           89
# 1242                                   muscle tightness           87
# 441                                   confusional state           85
# 1362                           oropharyngeal discomfort           83
# 821                                     head discomfort           81
# 1989                                  visual impairment           81
# 966                       influenza virus test negative           80
# 662                                            eye pain           80
# 1433                            pharyngeal paraesthesia           79
# 1116  loss of personal independence in daily activities           78
# 1328                                  oedema peripheral           77
# 1194                     metabolic function test normal           76
# 890                                         hypersomnia           76
# 1895                                  unevaluable event           75
# 1288                                        nervousness           75
# 663                                        eye pruritus           74
# 1607                                           retching           73
# 1065                             laboratory test normal           72
# 974                             injection site bruising           71
# 1380                                        pain in jaw           70
# 1440                                        photophobia           69
# 917                                         hypotension           69
# 62                                anaphylactic reaction           69
# 850                                       herpes zoster           68
# 377                                          cellulitis           66
# 154                                    balance disorder           66
# 1775                                     taste disorder           64
# 1952                          vaccination site swelling           63
# 1381                                       pain of skin           63
# 999                               injection site nodule           62
# 1507                              product storage error           60
# 579                                      ear discomfort           60
# 1059                                     joint swelling           60
# 644                           exposure during pregnancy           59
# 1111                                     local reaction           57
# 1067                              lacrimation increased           55
# 1323                                  ocular hyperaemia           55
# 1243                                   muscle twitching           54
# 544                            disturbance in attention           54
# 308                                           bone pain           54
# 559                                          dry throat           54
# 596                          electrocardiogram abnormal           53
# 1716                                           sneezing           53
# 451                                           contusion           52
# 1910                                     urine analysis           52
# 701                  feeling of body temperature change           52
# 422                               computerised tomogram           50
# 498                                               death           50
# 1896                            unresponsive to stimuli           49
# 1289                                          neuralgia           49
# 1422                               periorbital swelling           48
# 541                                      disorientation           47
# 700                                     feeling jittery           47
# 1495  product administered to patient of inappropria...           47
# 1057                    joint range of motion decreased           46
# 1275                                    nasopharyngitis           45
# 659                                      eye irritation           45
# 503                                         dehydration           45
# 227                             blood glucose increased           45
# 1494         product administered at inappropriate site           44
# 1431                           pharyngeal hypoaesthesia           43
# 1931                          vaccination site erythema           43
# 1501                            product label confusion           43
# 990                         injection site inflammation           42
# 1795                                    throat clearing           42
# 2024                         wrong product administered           42
# 1358                                      oral pruritus           41
# 825                                          heart rate           41
# 1682                                skin discolouration           41
# 1058                                    joint stiffness           40
# 547                                  dizziness postural           40
# 1862                                    troponin normal           40
# 2017                   white blood cell count increased           39
# 265                            blood pressure decreased           39
# 1762                                 swelling of eyelid           39
# 689                                                fall           39
# 986                        injection site hypoaesthesia           38
# 1004                        injection site paraesthesia           38
# 1723                                    speech disorder           38
# 1510                                   productive cough           38
# 1857                                           troponin           38
# 1374                        oxygen saturation decreased           37
# 1681                             skin burning sensation           37
# 1605                                       restlessness           37
# 975                           injection site cellulitis           37
# 129                                              asthma           36
# 979                           injection site discomfort           36
# 397                                         chromaturia           12
# 350                               carbon dioxide normal           12
# 903                                   hypoaesthesia eye           12
# 1573           red blood cell sedimentation rate normal           11
# 1171                       mean cell haemoglobin normal           11
# 2013                                    wheelchair user           11
# 1479                            pregnancy test negative           11
# 488                                       culture urine           11
# 1650                             seizure like phenomena           11
# 70                                            angiogram           11
# 2032                                       x-ray normal           11
# 192                              blood bilirubin normal           11
# 1890                           ultrasound scan abnormal           11
# 196                                blood calcium normal           11
# 1041                                      investigation           11
# 1519                               protein total normal           11
# 1299                         neutrophil count increased           11
# 660                               eye movement disorder           11
# 439                 computerised tomogram thorax normal           11
# 994                           injection site joint pain           11
# 333                                        bronchospasm           11
# 41                   alanine aminotransferase increased           11
# 119                                           arthritis           11
# 622                                      enlarged uvula           11
# 818                                       hallucination           11
# 1248                               musculoskeletal pain           11
# 647                           exposure via skin contact           11
# 1588                                 respiratory arrest           11
# 651                                       extrasystoles           11
# 1949                              vaccination site rash           10
# 11                                      abnormal dreams           10
# 139                                                aura           10
# 811                               haemoglobin decreased           10
# 2009                                             weight           10
# 1212                              monocyte count normal           10
# 1213                                monocyte percentage           10
# 1134                         lymphocyte count decreased           10
# 1602                            respiratory viral panel           10
# 1793                                  thinking abnormal           10
# 822                                         head injury           10
# 1908                            urinary tract infection           10
# 1279                                       needle issue           10
# 535          differential white blood cell count normal           10
# 444                                      conjunctivitis           10
# 1465                          polymerase chain reaction           10
# 1674                                     sinus headache           10
# 1743                                             stress           10
# 1463                                        pollakiuria           10
# 1321                occupational exposure to sars-cov-2           10
# 1673                                     sinus disorder           10
# 1353                            oral mucosal blistering           10
# 412                                  cognitive disorder           10
# 985                     injection site hypersensitivity           10
# 1033              international normalised ratio normal           10
# 743                           gastrointestinal disorder           10
# 304                           body temperature abnormal           10
# 752                                          gaze palsy            9
# 619                             endotracheal intubation            9
# 1190                                  mental impairment            9
# 871                        human chorionic gonadotropin            9
# 327                                   breast tenderness            9
# 698                                       feeling drunk            9
# 178                                           blindness            9
# 2011                                   weight decreased            9
# 2010                          weight bearing difficulty            9
# 348                            carbon dioxide decreased            9
# 1956                                vaginal haemorrhage            9
# 1256                  myocardial necrosis marker normal            9
# 1420                                 periorbital oedema            9
# 351                                      cardiac arrest            9
# 1625                  sars-cov-2 antibody test negative            9
# 873               human chorionic gonadotropin negative            9
# 746                               gastrointestinal pain            9
# 2025           wrong technique in product usage process            9
# 64                               anaphylactoid reaction            9
# 1178                        mean platelet volume normal            9
# 467                                  covid-19 pneumonia            9
# 675                                    eyelids pruritus            9
# 109                                      appendicectomy            9
# 1296                              neuropathy peripheral            9
# 1303                    neutrophil percentage increased            9
# 795                                          groin pain            9
# 627                               eosinophil percentage            8
# 1993                            vital signs measurement            8
# 81                                            anion gap            8
# 995                      injection site lymphadenopathy            8
# 110                                        appendicitis            8
# 289            blood thyroid stimulating hormone normal            8
# 1129                                lymph node palpable            8
# 1013                           injection site streaking            8
# 626                             eosinophil count normal            8
# 1450                           platelet count decreased            8
# 114                                          arrhythmia            8
# 1413                                        pelvic pain            8
# 1372                                  oxygen saturation            8
# 1354                              oral mucosal eruption            8
# 779                glomerular filtration rate decreased            8
# 780                   glomerular filtration rate normal            8
# 194                             blood calcium decreased            8
# 383                                           cheilitis            8
# 1241                                    muscle swelling            8
# 920                                           hypotonia            8
# 1636                                 scan with contrast            8
# 13                                 abortion spontaneous            8
# 914                                           hypopnoea            8
# 1532                               pulmonary congestion            8
# 1679                                          sinusitis            8
# 1238                                    muscle rigidity            8
# 12                            abnormal sensation in eye            8
# 1943               vaccination site movement impairment            8
# 10                                   abnormal behaviour            8
# 1622                            salivary hypersecretion            8
# 1540                                       pulse absent            8
# 1108                                liver function test            8
# 1585                                         renal pain            8
# 1776                                        tearfulness            8
# 1626                  sars-cov-2 antibody test positive            8
# 726                                         formication            8
# 1090                                        lip blister            8
# 1402                     paranasal sinus hypersecretion            8
# 729                            frequent bowel movements            8
# 1568                     red blood cell count decreased            8
# 952                    increased upper airway secretion            8
# 1221                                    motion sickness            8
# 577                                             dysuria            8
# 970                                    initial insomnia            8
# 280                              blood sodium decreased            8
# 1523                                   prothrombin time            8
# 826                                 heart rate abnormal            8
# 438               computerised tomogram thorax abnormal            8
# 655                                     eye haemorrhage            8
# 505                                            delirium            8
# 1252                                          mydriasis            8
# 1572        red blood cell sedimentation rate increased            8
# 1185                                        menorrhagia            8
# 39                                            agitation            8
# 1140                                        lymphoedema            7
# 653                                       eye discharge            7
# 1138                    lymphocyte percentage decreased            7
# 578                                      ear congestion            7
# 597                        electrocardiogram ambulatory            7
# 1647                                secretion discharge            7
# 640                                  erythema of eyelid            7
# 1538                                     pulmonary pain            7
# 191                           blood bilirubin increased            7
# 342                           c-reactive protein normal            7
# 187                blood alkaline phosphatase increased            7
# 775                                         glassy eyes            7
# 778                          glomerular filtration rate            7
# 1675                                    sinus operation            7
# 786                            glycosylated haemoglobin            7
# 211                 blood creatine phosphokinase normal            7
# 1300                            neutrophil count normal            7
# 219                           blood electrolytes normal            7
# 353                                  cardiac discomfort            7
# 1442                          photosensitivity reaction            7
# 1606                                      resuscitation            7
# 243                         blood lactic acid decreased            7
# 326                                     breast swelling            7
# 1689                                    skin induration            7
# 1295                               neurological symptom            7
# 835                                         hemiparesis            7
# 1338                       ophthalmological examination            7
# 300                                 blood urine present            7
# 845                                      herpes simplex            7
# 1227                                   mouth ulceration            7
# 424              computerised tomogram abdomen abnormal            7
# 628                     eosinophil percentage decreased            7
# 1163            maternal exposure during breast feeding            7
# 513                                      depressed mood            7
# 1858                                         troponin i            7
# 144                                           autoscopy            7
# 497                                 deafness unilateral            7
# 973                              injection site abscess            7
# 116                          arteriogram carotid normal            7
# 944                                          incoherent            7
# 1856                                            trismus            7
# 1456                                     pleuritic pain            7
# 160                               basophil count normal            7
# 1161                               mastication disorder            7
# 1125                                  lung infiltration            7
# 162                       basophil percentage decreased            7
# 1253                              myocardial infarction            7
# 634                                         epinephrine            6
# 1094                                       lip erythema            6
# 881                                      hyperglycaemia            6
# 686                                  faeces discoloured            6
# 1695                                          skin mass            6
# 814                                         haemorrhage            6
# 997                  injection site movement impairment            6
# 1642                                            scratch            6
# 800                               haematocrit decreased            6
# 636                                          eructation            6
# 781                                           glossitis            6
# 1110                         liver function test normal            6
# 1109                      liver function test increased            6
# 771                                       gingival pain            6
# 1640                                           sciatica            6
# 678                                    facial asymmetry            6
# 1638                          scan with contrast normal            6
# 732                           full blood count abnormal            6
# 654                                        eye disorder            6
# 1632                                               scab            6
# 1105                                             lipids            6
# 1318                       obstructive airways disorder            6
# 1051                                       jaw disorder            6
# 1030                     international normalised ratio            6
# 798                                       haematochezia            6
# 677                                         face oedema            6
# 1545                                            pustule            6
# 1136                            lymphocyte count normal            6
# 1975                                 vertigo positional            6
# 1247                           musculoskeletal disorder            6
# 329                              breath sounds abnormal            6
# 1447                                       piloerection            6
# 165                                        bell's palsy            6
# 1600                       respiratory tract irritation            6
# 1455                                           pleurisy            6
# 74                            angiogram cerebral normal            6
# 368                           cardiovascular evaluation            6
# 1292                           neurological examination            6
# 369                                       cardioversion            6
# 549                                            drooling            6
# 2027                                     x-ray abnormal            6
# 1385                                   palatal swelling            6
# 49                                   allergy to vaccine            6
# 52                       altered state of consciousness            6
# 517                                          dermatitis            6
# 107                                      aphthous ulcer            6
# 442                            conjunctival haemorrhage            6
# 453                               coordination abnormal            6
# 1590                               respiratory distress            6
# 66                                      angina pectoris            6
# 2000                                  vitreous floaters            6
# 1478                                     pregnancy test            6
# 1294                    neurological examination normal            6
# 2004                                vomiting projectile            6
# 295                blood urea nitrogen/creatinine ratio            6
# 1228                                  movement disorder            6
# 1441                                          photopsia            6
# 611                                electroencephalogram            6
# 278                   blood pressure systolic increased            6
# 1927                          vaccination site bruising            6
# 1950                          vaccination site reaction            6
# 1930                        vaccination site discomfort            6
# 216                                       blood culture            6
# 624                          eosinophil count decreased            6
# 208                        blood creatine phosphokinase            6
# 591                                              eczema            6
# 590                               echocardiogram normal            6
# 1272                                     nasal pruritus            5
# 115                                 arteriogram carotid            5
# 1742                        streptococcus test positive            5
# 1509                                  product use issue            5
# 1683                                    skin discomfort            5
# 1277                                          neck mass            5
# 982                        injection site extravasation            5
# 1937                      vaccination site inflammation            5
# 446                           consciousness fluctuating            5
# 1987                                visual field defect            5
# 1996                                 vitamin b12 normal            5
# 450                     contraindication to vaccination            5
# 1120                                    lumbar puncture            5
# 1560                                      rash pustular            5
# 1397                                   paraesthesia ear            5
# 869                                        hospice care            5
# 1860                                  troponin i normal            5
# 89                                        antibody test            5
# 1983                                viral test negative            5
# 1240                                      muscle strain            5
# 1880                                 ultrasound doppler            5
# 907                                          hypogeusia            5
# 1089                                          limb mass            5
# 315                           brain natriuretic peptide            5
# ...
# 1084                                      ligament pain            1
# 1083                                lid sulcus deepened            1
# 1079                                    legionella test            1
# 1078  left ventricular end-diastolic pressure increased            1
# 1077                                           laziness            1
# 1076                                       laryngoscopy            1
# 1117                  low density lipoprotein increased            1
# 1126                            lung neoplasm malignant            1
# 1133                                   lymphocyte count            1
# 1141                                           lysozyme            1
# 1149                   magnetic resonance imaging joint            1
# 1150                    magnetic resonance imaging neck            1
# 1153         magnetic resonance imaging spinal abnormal            1
# 1156                                       malnutrition            1
# 1157                                          mammogram            1
# 897                                         hypertrophy            1
# 899                                      hypervigilance            1
# 900                           hypnopompic hallucination            1
# 905                                       hypocalcaemia            1
# 906                                          hypocapnia            1
# 911                                       hyponatraemia            1
# 913                                   hypophosphataemia            1
# 922                                        hysteroscopy            1
# 923                                ill-defined disorder            1
# 935                           immunoglobulins decreased            1
# 977                           injection site dermatitis            1
# 937                           impaired gastric emptying            1
# 939                               implant site pruritus            1
# 940                                 impulsive behaviour            1
# 941                                inappropriate affect            1
# 943                                 incisional drainage            1
# 945                    incomplete course of vaccination            1
# 951                       increased insulin requirement            1
# 953   increased viscosity of upper respiratory secre...            1
# 955                                 infant irritability            1
# 957                            infectious mononucleosis            1
# 959                            inflammatory marker test            1
# 968             infusion site joint movement impairment            1
# 969                                infusion site warmth            1
# 972                          injection related reaction            1
# 2035                                        yellow skin            1

# %%
#Filter symptoms with more than 40 occurrences
symptoms_to_keep = symptom_table_sorted[symptom_table_sorted['Occurrences'] > 40]['Symptom'].tolist()
len(symptoms_to_keep)
# Out:
# 204

# %%
# Get the original columns
original_cols = df.columns[:14].tolist()
original_cols
# Out:
# ['VAERS_ID',
#  'STATE',
#  'AGE_YRS',
#  'SEX',
#  'DIED',
#  'L_THREAT',
#  'HOSPITAL',
#  'DISABLE',
#  'RECOVD',
#  'VAX_DATE',
#  'BIRTH_DEFECT',
#  'VAX_LOT',
#  'VAX_MANU',
#  'VAX_DOSE_SERIES']

# %%
columns_to_keep = original_cols + symptoms_to_keep

# %%
# Define the aggregation dictionary
agg_dict = {col: "max" for col in symptoms_to_keep}  # Max for all symptom columns
agg_dict.update({col: "first" for col in df.columns if col not in symptoms_to_keep})  # Keep first for the rest
# Group by ‘vars ID’ and apply the aggregation
df_merged = df.groupby("VAERS_ID").agg(agg_dict).reset_index()
# Display the result
print(df_merged.head())

# %%
cleaned_sympt_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 cleaned_sympt_df
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\IPython\core\displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\IPython\core\displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\IPython\core\formatters.py:182, in DisplayFormatter.format(self, obj, include, exclude)
#     180 md = None
#     181 try:
# --> 182     data = formatter(obj)
#     183 except:
#     184     # FIXME: log the exception
#     185     raise
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\IPython\core\formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\IPython\core\formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\core\frame.py:1256, in DataFrame._repr_html_(self)
#    1234     show_dimensions = get_option("display.show_dimensions")
#    1236     formatter = fmt.DataFrameFormatter(
#    1237         self,
#    1238         columns=None,
#    (...)
#    1254         decimal=".",
#    1255     )
# -> 1256     return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#    1257 else:
#    1258     return None
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\io\formats\format.py:936, in DataFrameRenderer.to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#     927 Klass = NotebookFormatter if notebook else HTMLFormatter
#     929 html_formatter = Klass(
#     930     self.fmt,
#     931     classes=classes,
#    (...)
#     934     render_links=render_links,
#     935 )
# --> 936 string = html_formatter.to_string()
#     937 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\io\formats\html.py:88, in HTMLFormatter.to_string(self)
#      87 def to_string(self) -> str:
# ---> 88     lines = self.render()
#      89     if any(isinstance(x, str) for x in lines):
#      90         lines = [str(x) for x in lines]
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\io\formats\html.py:644, in NotebookFormatter.render(self)
#     642 self.write("<div>")
#     643 self.write_style()
# --> 644 super().render()
#     645 self.write("</div>")
#     646 return self.elements
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\io\formats\html.py:94, in HTMLFormatter.render(self)
#      93 def render(self) -> list[str]:
# ---> 94     self._write_table()
#      96     if self.should_show_dimensions:
#      97         by = chr(215)  # ×  # noqa: RUF003
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\io\formats\html.py:269, in HTMLFormatter._write_table(self, indent)
#     266 if self.fmt.header or self.show_row_idx_names:
#     267     self._write_header(indent + self.indent_delta)
# --> 269 self._write_body(indent + self.indent_delta)
#     271 self.write("</table>", indent)
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\io\formats\html.py:417, in HTMLFormatter._write_body(self, indent)
#     415 def _write_body(self, indent: int) -> None:
#     416     self.write("<tbody>", indent)
# --> 417     fmt_values = self._get_formatted_values()
#     419     # write values
#     420     if self.fmt.index and isinstance(self.frame.index, MultiIndex):
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\io\formats\html.py:607, in NotebookFormatter._get_formatted_values(self)
#     606 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 607     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\io\formats\format.py:754, in DataFrameFormatter.format_col(self, i)
#     752 frame = self.tr_frame
#     753 formatter = self._get_formatter(i)
# --> 754 return format_array(
#     755     frame.iloc[:, i]._values,
#     756     formatter,
#     757     float_format=self.float_format,
#     758     na_rep=self.na_rep,
#     759     space=self.col_space.get(frame.columns[i]),
#     760     decimal=self.decimal,
#     761     leading_space=self.index,
#     762 )
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1161, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting, fallback_formatter)
#    1145     digits = get_option("display.precision")
#    1147 fmt_obj = fmt_klass(
#    1148     values,
#    1149     digits=digits,
#    (...)
#    1158     fallback_formatter=fallback_formatter,
#    1159 )
# -> 1161 return fmt_obj.get_result()
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1194, in _GenericArrayFormatter.get_result(self)
#    1193 def get_result(self) -> list[str]:
# -> 1194     fmt_values = self._format_strings()
#    1195     return _make_fixed_width(fmt_values, self.justify)
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1482, in _IntArrayFormatter._format_strings(self)
#    1480     formatter_str = lambda x: f"{x: d}".format(x=x)
#    1481 formatter = self.formatter or formatter_str
# -> 1482 fmt_values = [formatter(x) for x in self.values]
#    1483 return fmt_values
#
# KeyboardInterrupt:
